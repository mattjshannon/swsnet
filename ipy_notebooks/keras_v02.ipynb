# %% [markdown]
# # Significantly improved accuracy by normalizing spectra prior to NN

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import glob
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.core.debugger import set_trace as st
from sklearn.model_selection import train_test_split

print(tf.__version__)
# Out:
# 1.10.0

# %% [markdown]
# ## Dataset: ISO-SWS

# %%
# Needed directories
base_dir = '../data/isosws_atlas/'

# Pickles containing our spectra in the form of pandas dataframes:
spec_dir = base_dir + 'spectra/'
spec_files = np.sort(glob.glob(spec_dir + '*.pkl'))

# Metadata pickle (pd.dataframe). Note each entry contains a pointer to the corresponding spectrum pickle.
metadata = base_dir + 'metadata.pkl'

# %%
# Load the metadata pickle.
meta = pd.read_pickle(metadata)

# %%
meta
# Out:
#           object_name       tdt          ra        dec full_classifier group  \
# 0               W Cet  37802225    0.532083 -14.676639          2.SEa:     2
# 1              SV And  42801007    1.083333  40.110333          2.SEa:     2
# 2              SV And  80800708    1.083333  40.110333           2.SEa     2
# 3               CIT 1  78201008    1.717917  43.076667               7     7
# 4               HR 10  37802001    1.825833 -17.387000           1.NM:     1
# 5          {beta} Cas  28501420    2.293625  59.149944             1.N     1
# 6            V633 Cas  43501514    2.860833  58.834444            5.SE     5
# 7              NGC 40  44401917    3.253792  72.522222            4.PN     4
# 8              NGC 40  30003803    3.254583  72.521972            4.PN     4
# 9               HR 48  55502138    3.660000 -18.932889            1.NO     1
# 10              S Scl  73500129    3.842417 -32.045389           2.SEb     2
# 11              S Scl  37102018    3.842458 -32.045556           2.SEb     2
# 12    IRAS 00127+5437  39902101    3.850542  54.904278          4.SE::     4
# 13             VX And  42801502    4.975417  44.709722            2.CE     2
# 14              T Cet  55502308    5.441792 -20.058556           2.SEa     2
# 15              T Cet  37801819    5.444083 -20.057778           2.SEa     2
# 16         RAFGL 5017  54900858    5.450000 -40.286944          4.SEC:     4
# 17              T Cas  40201208    5.809375  55.792694           2.SEa     2
# 18    IRAS 00210+6221  40401901    5.963333  62.635278            4.CR     4
# 19    IRAS 00211+6549  44402001    5.991667  66.100889            5.F:     5
# 20              R And  40201723    6.008333  38.576944           2.SEc     2
# 21             47 Tuc  74803701    6.021250 -72.080694               7     7
# 22      Off-{beta}Hyi  17900204    6.428542 -77.254778               7     7
# 23         {beta} Hyi  85000604    6.433708 -77.254611             1.N     1
# 24      Off-{beta}Hyi   9200604    6.447250 -77.254806               7     7
# 25        {kappa} Phe  23200502    6.550667 -43.680306           1.NM:     1
# 26             VX Cas  42701004    7.833333  62.000000               7     7
# 27             RNO 1B  28500902    9.192750  63.481778             5.F     5
# 28               M 31  40001501   10.691708  41.269972               7     7
# 29               WR 1  42500402   10.868333  64.762361               7     7
# ...               ...       ...         ...        ...             ...   ...
# 1209    {upsilon} Peg  21900653  351.344375  23.404111            1.N:     1
# 1210         NGC 7662  43700427  351.474417  42.534833            4.PN     4
# 1211            Hb 12  43700330  351.561167  58.181861          4.SECe     4
# 1212           RU Phe  34401919  352.034583 -47.458139          2.SEc:     2
# 1213        AFGL 3099  78200523  352.070417  10.911111            3.CR     3
# 1214  IRAS 23262+6401  43305805  352.115417  64.292472            5.SA     5
# 1215         V582 Cas  38501620  352.545208  60.276139           2.SEc     2
# 1216         V582 Cas  42300804  352.613875  57.976250           2.SEc     2
# 1217  IRAS 23304+6147  24800452  353.187250  62.063750            4.CT     4
# 1218  IRAS 23304+6147  39601867  353.187250  62.063778            4.CT     4
# 1219  IRAS 23304+6147   8502452  353.187292  62.063750            4.CT     4
# 1220  IRAS 23321+6545  25500248  353.593875  66.030667           4.CN:     4
# 1221       IRC +40540  38201557  353.616083  43.550111            3.CR     3
# 1222    Nova Cas 1993  24800307  355.446625  57.517028               6     6
# 1223            R Aqr  18100530  355.955667 -15.284528           2.SEc     2
# 1224           PZ Cas   9502846  356.013750  61.789528           2.SEc     2
# 1225           PZ Cas  42604702  356.013750  61.789528           2.SEc     2
# 1226            Z Cas  10101714  356.131208  56.581278          2.SEap     2
# 1227           TX Psc  75700419  356.597917   3.486667            1.NC     1
# 1228           TX Psc  55501379  356.597917   3.486833            1.NC     1
# 1229          HR 9043  40400904  358.336625 -24.229250               7     7
# 1230           M 2-56  43700232  359.151958  70.803639            4.SB     4
# 1231            R Cas  24800223  359.603208  51.388528           2.SEb     2
# 1232            R Cas  26301524  359.603208  51.388556           2.SEb     2
# 1233            R Cas  38300825  359.603250  51.388556           2.SEb     2
# 1234            R Cas  39501330  359.603250  51.388556           2.SEb     2
# 1235            R Cas  42100215  359.603250  51.388556           2.SEb     2
# 1236            R Cas  44301926  359.603250  51.388556           2.SEb     2
# 1237            R Cas  62702122  359.603250  51.388556           2.SEb     2
# 1238            R Cas  38302016  359.603292  51.388667           2.SEb     2
#
#      subgroup uncertainty_flag note                    file_path  \
# 0         SEa                1          spectra/37802225_sws.pkl
# 1         SEa                1          spectra/42801007_sws.pkl
# 2         SEa                           spectra/80800708_sws.pkl
# 3                                 W     spectra/78201008_sws.pkl
# 4          NM                1          spectra/37802001_sws.pkl
# 5           N                           spectra/28501420_sws.pkl
# 6          SE                     W     spectra/43501514_sws.pkl
# 7          PN                           spectra/44401917_sws.pkl
# 8          PN                           spectra/30003803_sws.pkl
# 9          NO                           spectra/55502138_sws.pkl
# 10        SEb                           spectra/73500129_sws.pkl
# 11        SEb                           spectra/37102018_sws.pkl
# 12         SE                2          spectra/39902101_sws.pkl
# 13         CE                           spectra/42801502_sws.pkl
# 14        SEa                           spectra/55502308_sws.pkl
# 15        SEa                     F     spectra/37801819_sws.pkl
# 16        SEC                1          spectra/54900858_sws.pkl
# 17        SEa                           spectra/40201208_sws.pkl
# 18         CR                           spectra/40401901_sws.pkl
# 19          F                1          spectra/44402001_sws.pkl
# 20        SEc                           spectra/40201723_sws.pkl
# 21                                R     spectra/74803701_sws.pkl
# 22                                      spectra/17900204_sws.pkl
# 23          N                           spectra/85000604_sws.pkl
# 24                                F     spectra/09200604_sws.pkl
# 25         NM                1          spectra/23200502_sws.pkl
# 26                                W     spectra/42701004_sws.pkl
# 27          F                           spectra/28500902_sws.pkl
# 28                                G     spectra/40001501_sws.pkl
# 29                                      spectra/42500402_sws.pkl
# ...       ...              ...  ... ..                       ...
# 1209        N                1          spectra/21900653_sws.pkl
# 1210       PN                           spectra/43700427_sws.pkl
# 1211     SECe                           spectra/43700330_sws.pkl
# 1212      SEc                1          spectra/34401919_sws.pkl
# 1213       CR                           spectra/78200523_sws.pkl
# 1214       SA                           spectra/43305805_sws.pkl
# 1215      SEc                           spectra/38501620_sws.pkl
# 1216      SEc                           spectra/42300804_sws.pkl
# 1217       CT                           spectra/24800452_sws.pkl
# 1218       CT                           spectra/39601867_sws.pkl
# 1219       CT                     F     spectra/08502452_sws.pkl
# 1220       CN                1          spectra/25500248_sws.pkl
# 1221       CR                           spectra/38201557_sws.pkl
# 1222                                    spectra/24800307_sws.pkl
# 1223      SEc                           spectra/18100530_sws.pkl
# 1224      SEc                           spectra/09502846_sws.pkl
# 1225      SEc                           spectra/42604702_sws.pkl
# 1226     SEap                           spectra/10101714_sws.pkl
# 1227       NC                           spectra/75700419_sws.pkl
# 1228       NC                           spectra/55501379_sws.pkl
# 1229                              R     spectra/40400904_sws.pkl
# 1230       SB                           spectra/43700232_sws.pkl
# 1231      SEb                           spectra/24800223_sws.pkl
# 1232      SEb                     F     spectra/26301524_sws.pkl
# 1233      SEb                           spectra/38300825_sws.pkl
# 1234      SEb                           spectra/39501330_sws.pkl
# 1235      SEb                           spectra/42100215_sws.pkl
# 1236      SEb                           spectra/44301926_sws.pkl
# 1237      SEb                           spectra/62702122_sws.pkl
# 1238      SEb                           spectra/38302016_sws.pkl
#
#         object_type  data_ok
# 0                S*     True
# 1              Mira     True
# 2              Mira     True
# 3              Mira     True
# 4              Star     True
# 5              Star     True
# 6               Ae*     True
# 7                PN     True
# 8                PN     True
# 9     Candidate_LP*     True
# 10             Mira     True
# 11             Mira     True
# 12               IR     True
# 13       semi-regV*     True
# 14               S*     True
# 15               S*     True
# 16             Mira     True
# 17             Mira     True
# 18               C*     True
# 19              YSO     True
# 20               S*     True
# 21             GlCl     True
# 22               V*     True
# 23               V*     True
# 24               V*     True
# 25             Star     True
# 26              Ae*     True
# 27             FUOr     True
# 28           Galaxy     True
# 29              WR*     True
# ...             ...      ...
# 1209            PM*     True
# 1210             PN     True
# 1211                    True
# 1212           Mira     True
# 1213           Mira     True
# 1214             IR     True
# 1215     semi-regV*     True
# 1216     semi-regV*     True
# 1217      post-AGB*     True
# 1218      post-AGB*     True
# 1219      post-AGB*     True
# 1220             C*     True
# 1221           Mira     True
# 1222           Nova     True
# 1223     Symbiotic*     True
# 1224     semi-regV*     True
# 1225     semi-regV*     True
# 1226           Mira     True
# 1227             C*     True
# 1228             C*     True
# 1229           Star     True
# 1230                    True
# 1231           Mira     True
# 1232           Mira     True
# 1233           Mira     True
# 1234           Mira     True
# 1235           Mira     True
# 1236           Mira     True
# 1237           Mira     True
# 1238           Mira     True
#
# [1239 rows x 13 columns]

# %% [markdown]
# ### Labels

# %%
# Simple classifier first.
labels = meta['group'].values.astype(int)

# %%
# The possible labels.
np.unique(labels)
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
# SHIFTING TO START AT ZERO!
labels = labels - 1

# %% [markdown]
# #### Labels ('group'):
#
# 1. Naked stars
# 2. Stars with dust
# 3. Warm, dusty objects
# 4. Cool, dusty objects
# 5. Very red objects
# 6. Continuum-free objects but having emission lines
# 7. Flux-free and/or fatally flawed spectra

# %%
# See how the labels are distributed.
plt.plot(labels);

# %%
# Shuffle data at some point.

# %%
type(labels[0])
# Out:
# numpy.int64

# %%
# Make sure each sample has a valid label.
np.sum(np.isfinite(labels)) == len(labels)
# Out:
# True

# %%
len(labels)
# Out:
# 1239

# %%
# knowing that each sample has a 359-point vector/spectrum.
features = np.zeros((len(labels), 359))

# %% [markdown]
# ### Features

# %%
def load_spectrum(path):
    df = pd.read_pickle(path)
    flux = df['flux']
    return flux / np.nanmax(flux)

index = 0
# Fill the 'spectra' variable with the astronomical data.
for row in meta.itertuples(index=True, name='Pandas'):
    flux = load_spectrum(base_dir + row.file_path)
    features[index] = flux
    index += 1

# %%
features.shape
# Out:
# (1239, 359)

# %%
maxvec = np.nanmax(features, axis=1)

# %% [markdown]
# # Split into training and test sets

# %% [markdown]
# Data as...
# - feaatures (1239, 359)
# - labels (1239)

# %%
X_train, X_test, y_train, y_test = \
train_test_split(features, labels, test_size=0.33, random_state = 22)

# %%
X_train.shape
# Out:
# (830, 359)

# %%
X_test.shape
# Out:
# (409, 359)

# %%
y_train.shape
# Out:
# (830,)

# %%
y_test.shape
# Out:
# (409,)

# %% [markdown]
# # Model 1. NN

# %%
model = keras.Sequential()
# Adds a densely-connected layer with 64 units to the model:
model.add(keras.layers.Dense(64, activation='relu'))
# Add another:
model.add(keras.layers.Dense(64, activation='relu'))
# Add another:
model.add(keras.layers.Dense(64, activation='relu'))
# Add another:
model.add(keras.layers.Dense(32, activation='relu'))
# Add a softmax layer with 7 output units:
model.add(keras.layers.Dense(7, activation='softmax'))

# %%
model.compile(optimizer=tf.train.AdamOptimizer(0.0005),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# # Configure a model for categorical classification.
# model.compile(optimizer=tf.train.RMSPropOptimizer(0.001),
#               loss=keras.losses.sparse_categorical_crossentropy,
#               metrics=[keras.metrics.categorical_accuracy])

# %%
model.fit(features, labels, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 1239/1239 [==============================] - 0s 237us/step - loss: 1.6637 - acc: 0.3801
# Epoch 2/100
# 1239/1239 [==============================] - 0s 64us/step - loss: 1.3185 - acc: 0.5028
# Epoch 3/100
# 1239/1239 [==============================] - 0s 62us/step - loss: 1.1405 - acc: 0.5908
# Epoch 4/100
# 1239/1239 [==============================] - 0s 67us/step - loss: 0.9901 - acc: 0.6521
# Epoch 5/100
# 1239/1239 [==============================] - 0s 67us/step - loss: 0.8979 - acc: 0.6812
# Epoch 6/100
# 1239/1239 [==============================] - 0s 55us/step - loss: 0.8285 - acc: 0.6917
# Epoch 7/100
# 1239/1239 [==============================] - 0s 57us/step - loss: 0.7714 - acc: 0.7143
# Epoch 8/100
# 1239/1239 [==============================] - 0s 64us/step - loss: 0.7266 - acc: 0.7248
# Epoch 9/100
# 1239/1239 [==============================] - 0s 63us/step - loss: 0.7097 - acc: 0.7240
# Epoch 10/100
# 1239/1239 [==============================] - 0s 63us/step - loss: 0.6529 - acc: 0.7409
# Epoch 11/100
# 1239/1239 [==============================] - 0s 64us/step - loss: 0.6408 - acc: 0.7409
# Epoch 12/100
# 1239/1239 [==============================] - 0s 66us/step - loss: 0.6118 - acc: 0.7530
# Epoch 13/100
# 1239/1239 [==============================] - 0s 60us/step - loss: 0.5781 - acc: 0.7756
# Epoch 14/100
# 1239/1239 [==============================] - 0s 58us/step - loss: 0.5770 - acc: 0.7724
# Epoch 15/100
# 1239/1239 [==============================] - 0s 62us/step - loss: 0.5789 - acc: 0.7692
# Epoch 16/100
# 1239/1239 [==============================] - 0s 62us/step - loss: 0.5674 - acc: 0.7732
# Epoch 17/100
# 1239/1239 [==============================] - 0s 65us/step - loss: 0.5685 - acc: 0.7748
# Epoch 18/100
# 1239/1239 [==============================] - 0s 57us/step - loss: 0.5366 - acc: 0.7902
# Epoch 19/100
# 1239/1239 [==============================] - 0s 58us/step - loss: 0.5164 - acc: 0.8079
# Epoch 20/100
# 1239/1239 [==============================] - 0s 59us/step - loss: 0.4822 - acc: 0.8281
# Epoch 21/100
# 1239/1239 [==============================] - 0s 58us/step - loss: 0.4947 - acc: 0.8136
# Epoch 22/100
# 1239/1239 [==============================] - 0s 54us/step - loss: 0.4749 - acc: 0.8273
# Epoch 23/100
# 1239/1239 [==============================] - 0s 53us/step - loss: 0.4587 - acc: 0.8297
# Epoch 24/100
# 1239/1239 [==============================] - 0s 57us/step - loss: 0.4826 - acc: 0.8152
# Epoch 25/100
# 1239/1239 [==============================] - 0s 63us/step - loss: 0.4316 - acc: 0.8507
# Epoch 26/100
# 1239/1239 [==============================] - 0s 61us/step - loss: 0.4247 - acc: 0.8467
# Epoch 27/100
# 1239/1239 [==============================] - 0s 61us/step - loss: 0.4174 - acc: 0.8596
# Epoch 28/100
# 1239/1239 [==============================] - 0s 62us/step - loss: 0.3994 - acc: 0.8547
# Epoch 29/100
# 1239/1239 [==============================] - 0s 63us/step - loss: 0.4023 - acc: 0.8668
# Epoch 30/100
# 1239/1239 [==============================] - 0s 64us/step - loss: 0.3781 - acc: 0.8684
# Epoch 31/100
# 1239/1239 [==============================] - 0s 63us/step - loss: 0.3816 - acc: 0.8701
# Epoch 32/100
# 1239/1239 [==============================] - 0s 61us/step - loss: 0.4003 - acc: 0.8475
# Epoch 33/100
# 1239/1239 [==============================] - 0s 60us/step - loss: 0.3558 - acc: 0.8717
# Epoch 34/100
# 1239/1239 [==============================] - 0s 64us/step - loss: 0.3639 - acc: 0.8668
# Epoch 35/100
# 1239/1239 [==============================] - 0s 59us/step - loss: 0.3443 - acc: 0.8830
# Epoch 36/100
# 1239/1239 [==============================] - 0s 59us/step - loss: 0.3630 - acc: 0.8668
# Epoch 37/100
# 1239/1239 [==============================] - 0s 61us/step - loss: 0.3489 - acc: 0.8741
# Epoch 38/100
# 1239/1239 [==============================] - 0s 59us/step - loss: 0.3558 - acc: 0.8692
# Epoch 39/100
# 1239/1239 [==============================] - 0s 57us/step - loss: 0.3278 - acc: 0.8854
# Epoch 40/100
# 1239/1239 [==============================] - 0s 59us/step - loss: 0.3075 - acc: 0.8935
# Epoch 41/100
# 1239/1239 [==============================] - 0s 60us/step - loss: 0.3010 - acc: 0.8943
# Epoch 42/100
# 1239/1239 [==============================] - 0s 60us/step - loss: 0.3003 - acc: 0.8910
# Epoch 43/100
# 1239/1239 [==============================] - 0s 61us/step - loss: 0.2871 - acc: 0.9023
# Epoch 44/100
# 1239/1239 [==============================] - 0s 61us/step - loss: 0.2876 - acc: 0.8918
# Epoch 45/100
# 1239/1239 [==============================] - 0s 64us/step - loss: 0.2703 - acc: 0.9096
# Epoch 46/100
# 1239/1239 [==============================] - 0s 63us/step - loss: 0.2664 - acc: 0.9136
# Epoch 47/100
# 1239/1239 [==============================] - 0s 68us/step - loss: 0.2613 - acc: 0.9080
# Epoch 48/100
# 1239/1239 [==============================] - 0s 61us/step - loss: 0.2580 - acc: 0.9120
# Epoch 49/100
# 1239/1239 [==============================] - 0s 64us/step - loss: 0.2554 - acc: 0.9080
# Epoch 50/100
# 1239/1239 [==============================] - 0s 61us/step - loss: 0.2659 - acc: 0.9104
# Epoch 51/100
# 1239/1239 [==============================] - 0s 65us/step - loss: 0.2473 - acc: 0.9193
# Epoch 52/100
# 1239/1239 [==============================] - 0s 64us/step - loss: 0.2421 - acc: 0.9161
# Epoch 53/100
# 1239/1239 [==============================] - 0s 67us/step - loss: 0.2622 - acc: 0.9088
# Epoch 54/100
# 1239/1239 [==============================] - 0s 58us/step - loss: 0.2461 - acc: 0.9153
# Epoch 55/100
# 1239/1239 [==============================] - 0s 62us/step - loss: 0.2311 - acc: 0.9169
# Epoch 56/100
# 1239/1239 [==============================] - 0s 62us/step - loss: 0.2225 - acc: 0.9298
# Epoch 57/100
# 1239/1239 [==============================] - 0s 64us/step - loss: 0.2281 - acc: 0.9217
# Epoch 58/100
# 1239/1239 [==============================] - 0s 61us/step - loss: 0.2304 - acc: 0.9233
# Epoch 59/100
# 1239/1239 [==============================] - 0s 52us/step - loss: 0.2215 - acc: 0.9249
# Epoch 60/100
# 1239/1239 [==============================] - 0s 61us/step - loss: 0.2081 - acc: 0.9274
# Epoch 61/100
# 1239/1239 [==============================] - 0s 63us/step - loss: 0.1896 - acc: 0.9427
# Epoch 62/100
# 1239/1239 [==============================] - 0s 58us/step - loss: 0.2207 - acc: 0.9169
# Epoch 63/100
# 1239/1239 [==============================] - 0s 59us/step - loss: 0.2140 - acc: 0.9274
# Epoch 64/100
# 1239/1239 [==============================] - 0s 62us/step - loss: 0.2081 - acc: 0.9274
# Epoch 65/100
# 1239/1239 [==============================] - 0s 58us/step - loss: 0.1885 - acc: 0.9370
# Epoch 66/100
# 1239/1239 [==============================] - 0s 63us/step - loss: 0.1802 - acc: 0.9419
# Epoch 67/100
# 1239/1239 [==============================] - 0s 57us/step - loss: 0.1858 - acc: 0.9362
# Epoch 68/100
# 1239/1239 [==============================] - 0s 59us/step - loss: 0.1918 - acc: 0.9338
# Epoch 69/100
# 1239/1239 [==============================] - 0s 59us/step - loss: 0.1767 - acc: 0.9435
# Epoch 70/100
# 1239/1239 [==============================] - 0s 61us/step - loss: 0.1847 - acc: 0.9387
# Epoch 71/100
# 1239/1239 [==============================] - 0s 57us/step - loss: 0.1545 - acc: 0.9508
# Epoch 72/100
# 1239/1239 [==============================] - 0s 60us/step - loss: 0.2098 - acc: 0.9298
# Epoch 73/100
# 1239/1239 [==============================] - 0s 62us/step - loss: 0.1927 - acc: 0.9395
# Epoch 74/100
# 1239/1239 [==============================] - 0s 60us/step - loss: 0.1535 - acc: 0.9524
# Epoch 75/100
# 1239/1239 [==============================] - 0s 63us/step - loss: 0.1646 - acc: 0.9427
# Epoch 76/100
# 1239/1239 [==============================] - 0s 63us/step - loss: 0.1669 - acc: 0.9427
# Epoch 77/100
# 1239/1239 [==============================] - 0s 61us/step - loss: 0.1629 - acc: 0.9451
# Epoch 78/100
# 1239/1239 [==============================] - 0s 61us/step - loss: 0.1467 - acc: 0.9548
# Epoch 79/100
# 1239/1239 [==============================] - 0s 64us/step - loss: 0.1470 - acc: 0.9516
# Epoch 80/100
# 1239/1239 [==============================] - 0s 61us/step - loss: 0.1708 - acc: 0.9459
# Epoch 81/100
# 1239/1239 [==============================] - 0s 57us/step - loss: 0.1621 - acc: 0.9467
# Epoch 82/100
# 1239/1239 [==============================] - 0s 60us/step - loss: 0.1415 - acc: 0.9564
# Epoch 83/100
# 1239/1239 [==============================] - 0s 60us/step - loss: 0.1689 - acc: 0.9516
# Epoch 84/100
# 1239/1239 [==============================] - 0s 63us/step - loss: 0.1410 - acc: 0.9516
# Epoch 85/100
# 1239/1239 [==============================] - 0s 60us/step - loss: 0.1560 - acc: 0.9395
# Epoch 86/100
# 1239/1239 [==============================] - 0s 59us/step - loss: 0.1719 - acc: 0.9443
# Epoch 87/100
# 1239/1239 [==============================] - 0s 66us/step - loss: 0.1446 - acc: 0.9564
# Epoch 88/100
# 1239/1239 [==============================] - 0s 59us/step - loss: 0.1300 - acc: 0.9645
# Epoch 89/100
# 1239/1239 [==============================] - 0s 52us/step - loss: 0.1193 - acc: 0.9621
# Epoch 90/100
# 1239/1239 [==============================] - 0s 59us/step - loss: 0.1266 - acc: 0.9596
# Epoch 91/100
# 1239/1239 [==============================] - 0s 60us/step - loss: 0.1391 - acc: 0.9540
# Epoch 92/100
# 1239/1239 [==============================] - 0s 59us/step - loss: 0.1389 - acc: 0.9508
# Epoch 93/100
# 1239/1239 [==============================] - 0s 64us/step - loss: 0.3066 - acc: 0.9266
# Epoch 94/100
# 1239/1239 [==============================] - 0s 63us/step - loss: 0.2209 - acc: 0.9314
# Epoch 95/100
# 1239/1239 [==============================] - 0s 66us/step - loss: 0.2678 - acc: 0.9290
# Epoch 96/100
# 1239/1239 [==============================] - 0s 62us/step - loss: 0.1856 - acc: 0.9443
# Epoch 97/100
# 1239/1239 [==============================] - 0s 65us/step - loss: 0.1362 - acc: 0.9572
# Epoch 98/100
# 1239/1239 [==============================] - 0s 65us/step - loss: 0.1675 - acc: 0.9427
# Epoch 99/100
# 1239/1239 [==============================] - 0s 59us/step - loss: 0.1233 - acc: 0.9645
# Epoch 100/100
# 1239/1239 [==============================] - 0s 70us/step - loss: 0.1354 - acc: 0.9548

# %% [markdown]
# #### Test accuracy

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)

print('Test accuracy:', test_acc)
# Out:
# 409/409 [==============================] - 0s 190us/step
# Test accuracy: 0.9462102689486552

# %% [markdown]
# #### Check predictions

# %%
predictions = model.predict(X_test)

# %%
predicted_groups = [np.argmax(x) for x in predictions]

# %%
plt.hist(y_test, label='Actual labels');
plt.hist(predicted_groups, label='Predicted labels', alpha=0.7);
plt.legend(loc=0)

# %% [markdown]
# # Model 2. stochastic gradient descent

# %% [markdown]
# http://scikit-learn.org/stable/modules/sgd.html

# %%
from sklearn.linear_model import SGDClassifier
clf = SGDClassifier(loss="hinge", penalty="l2")
clf.fit(X_train, y_train)
SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
       eta0=0.0, fit_intercept=True, l1_ratio=0.15,
       learning_rate='optimal', loss='hinge', max_iter=None, n_iter=None,
       n_jobs=1, penalty='l2', power_t=0.5, random_state=None,
       shuffle=True, tol=None, verbose=0, warm_start=False)
# Out:
# /home/koma/miniconda3/envs/tf/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', max_iter=None, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=None,
#        shuffle=True, tol=None, verbose=0, warm_start=False)

# %%
predicted_labels = clf.predict(X_test)

# %%
test_acc = np.sum(predicted_labels == y_test) / len(y_test)

# %%
print('Test accuracy:', test_acc)
# Out:
# Test accuracy: 0.2982885085574572

# %%
plt.hist(y_test, label='Actual labels');
plt.hist(predicted_labels, label='Predicted labels', alpha=0.7);
plt.legend(loc=0)
